# %%
"""
projekt_1.py: první projekt do Engeto Online Python Akademie

author: Martin Jeřábek
email: martinjer90@gmail.com
discord: blbec908874
"""
import sys


registrovani={"bob":"123","ann":"pass123","mike":"password123","liz":"pass123"}

while True:
  jmeno=input("Zadej své jméno:")
  heslo=input("Zadej své heslo:")

  if jmeno in registrovani and registrovani[jmeno] == heslo:
    print("$ python projekt1.py")
    print("username: ", jmeno)
    print("password: ", heslo)
    print("-"*40)
    print("Welcome to the app, bob")
    print("We have 3 texts to be analyzed.")
    print("-"*40)
    break
  if (jmeno in registrovani or heslo
      in registrovani.values())and registrovani.get(jmeno) != heslo:
    print("Nesprávné jméno nebo heslo")
    continue
  else:
    print("$ python projekt1.py")
    print("username: ",jmeno)
    print("password: ",heslo)
    print("unregistered user, terminating the program..")
    sys.exit()

#------------------------------------------------------------------------------
TEXTS = ['''
Situated about 10 miles west of Kemmerer,
Fossil Butte is a ruggedly impressive
topographic feature that rises sharply
some 1000 feet above Twin Creek Valley
to an elevation of more than 7500 feet
above sea level. The butte is located just
north of US 30N and the Union Pacific Railroad,
which traverse the valley. ''',
'''At the base of Fossil Butte are the bright
red, purple, yellow and gray beds of the Wasatch
Formation. Eroded portions of these horizontal
beds slope gradually upward from the valley floor
and steepen abruptly. Overlying them and extending
to the top of the butte are the much steeper
buff-to-white beds of the Green River Formation,
which are about 300 feet thick.''',
'''The monument contains 8198 acres and protects
a portion of the largest deposit of freshwater fish
fossils in the world. The richest fossil fish deposits
are found in multiple limestone layers, which lie some
100 feet below the top of the butte. The fossils
represent several varieties of perch, as well as
other freshwater genera and herring similar to those
in modern oceans. Other fish such as paddlefish,
garpike and stingray are also present.'''
]

text_1=TEXTS[0].split()
text_2=TEXTS[1].split()
text_3=TEXTS[2].split()

text_11 = [x.strip() for x in text_1]
text_22 = [x.strip() for x in text_2]
text_33 = [x.strip() for x in text_3]

delka_1=len(text_11)
delka_2=len(text_22)
delka_3=len(text_33)

velka_1=sum(1 for word in text_11 if word[0].isupper())
velka_2=sum(1 for word in text_22 if word[0].isupper())
velka_3=sum(1 for word in text_33 if word[0].isupper())

caps_1=sum(1 for word in text_11 if word.isupper()
and not any(char.isdigit() for char in word))
caps_2=sum(1 for word in text_22 if word.isupper()
and not any(char.isdigit() for char in word))
caps_3=sum(1 for word in text_33 if word.isupper()
and not any(char.isdigit() for char in word))

low_1=sum(1 for word in text_11 if word.islower())
low_2=sum(1 for word in text_22 if word.islower())
low_3=sum(1 for word in text_33 if word.islower())

num_1=sum(1 for word in text_11 if word.isnumeric()
and not any(char.isalpha() for char in word))
num_2=sum(1 for word in text_22 if word.isnumeric()
and not any(char.isalpha() for char in word))
num_3=sum(1 for word in text_33 if word.isnumeric()
and not any(char.isalpha() for char in word))

sou_1=0
for word in text_11:
  if word.isdigit():
    sou_1+=int(word)


sou_2=0
for word in text_22:
  if word.isdigit():
    sou_2+=int(word)

sou_3=0
for word in text_33:
  if word.isdigit():
    sou_3+=int(word)


#------------------------------------------------------------------------------


while True:
  text=input("Enter a number btw. 1 and 3 to select: ")
  if text =="1":
    print("-"*40)
    print("There are",delka_1, "words in the selected text.")
    print("There are",velka_1, "titlecase words.")
    print("There are", caps_1, "uppercase words.")
    print("There are",low_1, "lowercase words.")
    print("There are",num_1,"numeric strings.")
    print("The sum of all the numbers", sou_1)
    print("-"*40)
    print(f'{"LEN":<2}|{" OCCURENCES":<12}|{"NR"}')
    print("-"*40)
    from collections import Counter
    delky_slov_1 = [len(slovo.strip('.,')) for slovo in text_1]
    cetnosti_1 = Counter(delky_slov_1)
    for delka, cetnost in sorted(cetnosti_1.items()):
      print(f'{delka:<2}|{"*" * cetnost:<12} |{cetnost}')
    print()
    break
  elif text =="2":
    print("-"*40)
    print("There are",delka_2, "words in the selected text.")
    print("There are",velka_2, "titlecase words.")
    print("There are", caps_2, "uppercase words.")
    print("There are",low_2, "lowercase words.")
    print("There are",num_2,"numeric strings.")
    print("The sum of all the numbers", sou_2)
    print("-"*40)
    print(f'{"LEN":<2}|{" OCCURENCES":<12}|{"NR"}')
    print("-"*40)
    from collections import Counter
    delky_slov_2 = [len(slovo.strip('.,')) for slovo in text_2]
    cetnosti_2 = Counter(delky_slov_2)
    for delka, cetnost in sorted(cetnosti_2.items()):
      print(f'{delka:<2}|{"*" * cetnost:<12} |{cetnost}')
    print()
    break
  elif text =="3":
    print("-"*40)
    print("There are",delka_3, "words in the selected text.")
    print("There are",velka_3, "titlecase words.")
    print("There are", caps_3, "uppercase words.")
    print("There are",low_3, "lowercase words.")
    print("There are",num_3,"numeric strings.")
    print("The sum of all the numbers", sou_3)
    print("-"*40)
    print(f'{"LEN":<2}|{" OCCURENCES":<12}|{"NR"}')
    print("-"*40)
    from collections import Counter
    delky_slov_3 = [len(slovo.strip('.,')) for slovo in text_3]
    cetnosti_3 = Counter(delky_slov_3)
    for delka, cetnost in sorted(cetnosti_3.items()):
      print(f'{delka:<2}|{"*" * cetnost:<12} |{cetnost}')
    print()
    break
  else:
    print("Zadal jsi špatné číslo. Ukončuji program.")
    sys.exit()
# Out:
# Zadej své jméno:bob
# Zadej své heslo:123
# $ python projekt1.py
# username:  bob
# password:  123
# ----------------------------------------
# Welcome to the app, bob
# We have 3 texts to be analyzed.
# ----------------------------------------
# Enter a number btw. 1 and 3 to select: 1
# ----------------------------------------
# There are 54 words in the selected text.
# There are 12 titlecase words.
# There are 1 uppercase words.
# There are 38 lowercase words.
# There are 3 numeric strings.
# The sum of all the numbers 8510
# ----------------------------------------
# LEN| OCCURENCES |NR
# ----------------------------------------
# 1 |*            |1
# 2 |*********    |9
# 3 |******       |6
# 4 |***********  |11
# 5 |************ |12
# 6 |***          |3
# 7 |****         |4
# 8 |*****        |5
# 9 |*            |1
# 10|*            |1
# 11|*            |1
